# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `c:\Users\stirn\Desktop\Bachelorarbeit\BaRepo\BioChemBA_PS`

# %%
using BiochemicalAlgorithms
using BiochemicalVisualization
using BiochemicalVisualization: display_model

# %%
fdb = FragmentDB()
AlaAla = load_pdb(ball_data_path("../test/data/AlaAla.pdb"))
normalize_names!(AlaAla, fdb);
build_bonds!(AlaAla, fdb);
reconstruct_fragments!(AlaAla, fdb);
# Out:
# ┌ Info: build_bonds!(): built 22 bonds
# └ @ BiochemicalAlgorithms C:\Users\stirn\.julia\packages\BiochemicalAlgorithms\g6ebH\src\preprocessing\build_bonds.jl:178
# ┌ Info: reconstruct_fragments!(): added 0 atoms.
# └ @ BiochemicalAlgorithms C:\Users\stirn\.julia\packages\BiochemicalAlgorithms\g6ebH\src\preprocessing\reconstruct_fragments.jl:185

# %%
atoms(AlaAla)
# Out:
# AtomTable{Float32} with 23 rows:
# ┌────┬─────┬────────┬─────────┬──────┬───────────┬──────────────────────────────
# │  # │ idx │ number │ element │ name │ atom_type │ r                           ⋯
# ├────┼─────┼────────┼─────────┼──────┼───────────┼──────────────────────────────
# │  1 │ 5   │ 1      │ N       │ N    │           │ Float32[-1.45, 0.0, 0.0]    ⋯
# │  2 │ 6   │ 2      │ C       │ CA   │           │ Float32[0.0, 0.0, 0.0]      ⋯
# │  3 │ 7   │ 3      │ C       │ C    │           │ Float32[0.495, 0.0, 1.437]  ⋯
# │  4 │ 8   │ 4      │ O       │ O    │           │ Float32[1.235, -0.911, 1.83 ⋯
# │  5 │ 9   │ 5      │ H       │ 1H   │           │ Float32[-1.788, 0.918, 0.25 ⋯
# │  6 │ 10  │ 6      │ H       │ 1HB  │           │ Float32[1.642, 1.124, -0.86 ⋯
# │  7 │ 11  │ 7      │ H       │ 2H   │           │ Float32[-1.801, -0.26, -0.9 ⋯
# │ ⋮  │  ⋮  │   ⋮    │    ⋮    │  ⋮   │     ⋮     │               ⋮             ⋱
# │ 18 │ 22  │ 18     │ H       │ 2HB  │           │ Float32[0.065, 3.039, 3.988 ⋯
# │ 19 │ 23  │ 19     │ H       │ 3HB  │           │ Float32[-1.16, 1.868, 4.519 ⋯
# │ 20 │ 24  │ 20     │ C       │ CB   │           │ Float32[-0.089, 2.07, 4.463 ⋯
# │ 21 │ 25  │ 21     │ H       │ HA   │           │ Float32[1.676, 1.185, 3.63] ⋯
# │ 22 │ 26  │ 22     │ O       │ O    │           │ Float32[0.531, -1.358, 3.42 ⋯
# │ 23 │ 27  │ 23     │ O       │ OXT  │           │ Float32[0.462, -0.512, 5.47 ⋯
# └────┴─────┴────────┴─────────┴──────┴───────────┴──────────────────────────────
#                                                    6 columns and 10 rows omitted

# %%
bonds(AlaAla)
# Out:
# BondTable{Float32} with 22 rows:
# ┌────┬─────┬────┬────┬────────┐
# │  # │ idx │ a1 │ a2 │ order  │
# ├────┼─────┼────┼────┼────────┤
# │  1 │ 28  │ 5  │ 13 │ Single │
# │  2 │ 29  │ 5  │ 6  │ Single │
# │  3 │ 30  │ 5  │ 9  │ Single │
# │  4 │ 31  │ 5  │ 11 │ Single │
# │  5 │ 32  │ 6  │ 16 │ Single │
# │  6 │ 33  │ 6  │ 7  │ Single │
# │  7 │ 34  │ 6  │ 15 │ Single │
# │ ⋮  │  ⋮  │ ⋮  │ ⋮  │   ⋮    │
# │ 17 │ 44  │ 19 │ 26 │ Double │
# │ 18 │ 45  │ 19 │ 27 │ Single │
# │ 19 │ 46  │ 21 │ 24 │ Single │
# │ 20 │ 47  │ 22 │ 24 │ Single │
# │ 21 │ 48  │ 23 │ 24 │ Single │
# │ 22 │ 49  │ 7  │ 17 │ Single │
# └────┴─────┴────┴────┴────────┘
#                  9 rows omitted
