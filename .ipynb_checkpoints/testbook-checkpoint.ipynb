# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `c:\Users\stirn\Desktop\Bachelorarbeit\BaRepo\BioChemBA_PS`

# %%
using BiochemicalAlgorithms
using BiochemicalVisualization
using BiochemicalVisualization: display_model, prepare_model

# %%
fdb = FragmentDB()
AlaAla = load_pdb(ball_data_path("../test/data/AlaAla.pdb"))
normalize_names!(AlaAla, fdb);
build_bonds!(AlaAla, fdb);
reconstruct_fragments!(AlaAla, fdb);
# Out:
# ┌ Info: build_bonds!(): built 22 bonds
# └ @ BiochemicalAlgorithms C:\Users\stirn\.julia\packages\BiochemicalAlgorithms\g6ebH\src\preprocessing\build_bonds.jl:178
# ┌ Info: reconstruct_fragments!(): added 0 atoms.
# └ @ BiochemicalAlgorithms C:\Users\stirn\.julia\packages\BiochemicalAlgorithms\g6ebH\src\preprocessing\reconstruct_fragments.jl:185

# %%
test_model = prepare_model(AlaAla)
# Out:
# BiochemicalVisualization.Representation{Float32}(Dict{String, AbstractVector{GeometryBasics.GeometryPrimitive{3, Float32}}}("spheres" => [GeometryBasics.Sphere{Float32}(Float32[-1.45, 0.0, 0.0], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.0, 0.0, 0.0], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.495, 0.0, 1.437], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[1.235, -0.911, 1.838], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-1.788, 0.918, 0.25], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[1.642, 1.124, -0.864], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-1.801, -0.26, -0.911], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.154, 1.136, -1.827], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-1.749, -0.665, 0.704], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.258, 2.118, -0.351], 0.4f0)  …  GeometryBasics.Sphere{Float32}(Float32[0.605, 0.98, 3.639], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.414, -0.408, 4.228], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-0.476, 1.73, 1.938], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.325, 2.106, 5.472], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.065, 3.039, 3.988], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-1.16, 1.868, 4.519], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[-0.089, 2.07, 4.463], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[1.676, 1.185, 3.63], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.531, -1.358, 3.421], 0.4f0), GeometryBasics.Sphere{Float32}(Float32[0.462, -0.512, 5.473], 0.4f0)], "cylinders" => [GeometryBasics.Cylinder{Float32}(Float32[-1.45, 0.0, 0.0], Float32[-1.5995, -0.3325, 0.352], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.5995, -0.3325, 0.352], Float32[-1.749, -0.665, 0.704], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.45, 0.0, 0.0], Float32[-0.725, 0.0, 0.0], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-0.725, 0.0, 0.0], Float32[0.0, 0.0, 0.0], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.45, 0.0, 0.0], Float32[-1.619, 0.459, 0.125], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.619, 0.459, 0.125], Float32[-1.788, 0.918, 0.25], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.45, 0.0, 0.0], Float32[-1.6255, -0.13, -0.4555], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.6255, -0.13, -0.4555], Float32[-1.801, -0.26, -0.911], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.0, 0.0, 0.0], Float32[0.1705, -0.464, -0.23], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.1705, -0.464, -0.23], Float32[0.341, -0.928, -0.46], 0.2f0)  …  GeometryBasics.Cylinder{Float32}(Float32[0.414, -0.408, 4.228], Float32[0.43800002, -0.46, 4.8505], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.43800002, -0.46, 4.8505], Float32[0.462, -0.512, 5.473], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.325, 2.106, 5.472], Float32[0.118, 2.0879998, 4.9674997], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.118, 2.0879998, 4.9674997], Float32[-0.089, 2.07, 4.463], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.065, 3.039, 3.988], Float32[-0.012000002, 2.5545, 4.2255], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-0.012000002, 2.5545, 4.2255], Float32[-0.089, 2.07, 4.463], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-1.16, 1.868, 4.519], Float32[-0.6245, 1.969, 4.491], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[-0.6245, 1.969, 4.491], Float32[-0.089, 2.07, 4.463], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.495, 0.0, 1.437], Float32[0.314, 0.49, 1.8525], 0.2f0), GeometryBasics.Cylinder{Float32}(Float32[0.314, 0.49, 1.8525], Float32[0.133, 0.98, 2.268], 0.2f0)]), AbstractVector{Union{Int64, AbstractString}}[["N", "N", 5, 2, 3], ["CA", "C", 6, 2, 3], ["C", "C", 7, 2, 3], ["O", "O", 8, 2, 3], ["1H", "H", 9, 2, 3], ["1HB", "H", 10, 2, 3], ["2H", "H", 11, 2, 3], ["2HB", "H", 12, 2, 3], ["3H", "H", 13, 2, 3], ["3HB", "H", 14, 2, 3]  …  ["CA", "C", 18, 2, 4], ["C", "C", 19, 2, 4], ["H", "H", 20, 2, 4], ["1HB", "H", 21, 2, 4], ["2HB", "H", 22, 2, 4], ["3HB", "H ...

# %%
test_model.meta_data
# Out:
# 23-element Vector{AbstractVector{Union{Int64, AbstractString}}}:
#  ["N", "N", 5, 2, 3]
#  ["CA", "C", 6, 2, 3]
#  ["C", "C", 7, 2, 3]
#  ["O", "O", 8, 2, 3]
#  ["1H", "H", 9, 2, 3]
#  ["1HB", "H", 10, 2, 3]
#  ["2H", "H", 11, 2, 3]
#  ["2HB", "H", 12, 2, 3]
#  ["3H", "H", 13, 2, 3]
#  ["3HB", "H", 14, 2, 3]
#  ⋮
#  ["C", "C", 19, 2, 4]
#  ["H", "H", 20, 2, 4]
#  ["1HB", "H", 21, 2, 4]
#  ["2HB", "H", 22, 2, 4]
#  ["3HB", "H", 23, 2, 4]
#  ["CB", "C", 24, 2, 4]
#  ["HA", "H", 25, 2, 4]
#  ["O", "O", 26, 2, 4]
#  ["OXT", "O", 27, 2, 4]

# %%
atoms(AlaAla)
# Out:
# AtomTable{Float32} with 23 rows:
# ┌────┬─────┬────────┬─────────┬──────┬───────────┬──────────────────────────────
# │  # │ idx │ number │ element │ name │ atom_type │ r                           ⋯
# ├────┼─────┼────────┼─────────┼──────┼───────────┼──────────────────────────────
# │  1 │ 5   │ 1      │ N       │ N    │           │ Float32[-1.45, 0.0, 0.0]    ⋯
# │  2 │ 6   │ 2      │ C       │ CA   │           │ Float32[0.0, 0.0, 0.0]      ⋯
# │  3 │ 7   │ 3      │ C       │ C    │           │ Float32[0.495, 0.0, 1.437]  ⋯
# │  4 │ 8   │ 4      │ O       │ O    │           │ Float32[1.235, -0.911, 1.83 ⋯
# │  5 │ 9   │ 5      │ H       │ 1H   │           │ Float32[-1.788, 0.918, 0.25 ⋯
# │  6 │ 10  │ 6      │ H       │ 1HB  │           │ Float32[1.642, 1.124, -0.86 ⋯
# │  7 │ 11  │ 7      │ H       │ 2H   │           │ Float32[-1.801, -0.26, -0.9 ⋯
# │ ⋮  │  ⋮  │   ⋮    │    ⋮    │  ⋮   │     ⋮     │               ⋮             ⋱
# │ 18 │ 22  │ 18     │ H       │ 2HB  │           │ Float32[0.065, 3.039, 3.988 ⋯
# │ 19 │ 23  │ 19     │ H       │ 3HB  │           │ Float32[-1.16, 1.868, 4.519 ⋯
# │ 20 │ 24  │ 20     │ C       │ CB   │           │ Float32[-0.089, 2.07, 4.463 ⋯
# │ 21 │ 25  │ 21     │ H       │ HA   │           │ Float32[1.676, 1.185, 3.63] ⋯
# │ 22 │ 26  │ 22     │ O       │ O    │           │ Float32[0.531, -1.358, 3.42 ⋯
# │ 23 │ 27  │ 23     │ O       │ OXT  │           │ Float32[0.462, -0.512, 5.47 ⋯
# └────┴─────┴────────┴─────────┴──────┴───────────┴──────────────────────────────
#                                                    6 columns and 10 rows omitted

# %%
atm = atom_by_idx(AlaAla, 7)
# Out:
# Atom{Float32}: (idx = 7, number = 3, element = BiochemicalAlgorithms.Elements.C, name = "C", atom_type = "", r = Float32[0.495, 0.0, 1.437], v = Float32[0.0, 0.0, 0.0], F = Float32[0.0, 0.0, 0.0], formal_charge = 0, charge = 0.0f0, radius = 0.0f0)

# %%
atm.formal
# Out:
# 3-element StaticArraysCore.SVector{3, Float32} with indices SOneTo(3):
#  0.495
#  0.0
#  1.437
